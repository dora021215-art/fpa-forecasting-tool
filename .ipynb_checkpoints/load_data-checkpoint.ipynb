# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Consolidate raw Yamato Holding's data so it can be used for prediction/forecasting

# %%
# load Yamato Holding's fpa data
df     = pd.read_excel("yamato_holdings_fpa.xlsx", sheet_name="Raw_Division_Data")
interco= pd.read_excel("yamato_holdings_fpa.xlsx", sheet_name="Interco_Elimination")
fx     = pd.read_excel("yamato_holdings_fpa.xlsx", sheet_name="FX_Reference")
issues = pd.read_excel("yamato_holdings_fpa.xlsx", sheet_name="Data_Quality_Log")

# Print basic info: dimension, divisions, and date range
print(f"Rows: {len(df)}, Columns: {len(df.columns)}")
print(f"Unique divisions : {df['division'].unique().tolist()}")
print(f"Date range: {df['ds'].min()} to {df['ds'].max()}")
print()
# Out:
# Rows: 72, Columns: 20
# Unique divisions : ['Japan Domestic', 'Asia Export', 'Corporate HQ']
# Date range: 2022-04-01 to 2024-03-01

# %%
df
# Out:
#             ds        division reporting_currency  usd_jpy_rate  \
# 0   2022-04-01  Japan Domestic                JPY           NaN
# 1   2022-04-01     Asia Export                USD         122.5
# 2   2022-04-01    Corporate HQ                JPY           NaN
# 3   2022-05-01  Japan Domestic                JPY           NaN
# 4   2022-05-01     Asia Export                USD         126.8
# ..         ...             ...                ...           ...
# 67  2024-02-01     Asia Export                USD         146.8
# 68  2024-02-01    Corporate HQ                JPY           NaN
# 69  2024-03-01  Japan Domestic                JPY           NaN
# 70  2024-03-01     Asia Export                USD         150.4
# 71  2024-03-01    Corporate HQ                JPY           NaN
#
#     rev_primary_jpy  rev_secondary_jpy  exp_headcount_jpy   exp_it_jpy  \
# 0         864901424          616543392          415181508  102615149.0
# 1         502997862           28696360          229343765   38058912.0
# 2          59700000                  0          173923013   55942741.0
# 3         807257554          606390431          410887380   89245032.0
# 4         579533694           22652820          232872891   42661860.0
# ..              ...                ...                ...          ...
# 67        718175694           29539389          276815328   44311286.0
# 68         62616000                  0          180595993   57254161.0
# 69        915231567          666208154          410384679   96298612.0
# 70        684540486           19858515          286187587   45539766.0
# 71         63048000                  0          173221758   56589412.0
#
#     exp_rent_jpy  exp_cogs_jpy  exp_compliance_jpy  interco_charge_jpy  \
# 0       65000000     559480177            27531726            45000000
# 1       22050000     219281125             9762392            14700000
# 2       38000000             0            12881544           -59700000
# 3       65000000     542497281            26798722            45000000
# 4       22824000     239544600            12257756            15216000
# ..           ...           ...                 ...                 ...
# 67      26424000     302250483            14833112            17616000
# 68      38000000             0            15815040           -62616000
# 69      65000000     586645871            29277184            45000000
# 70      27072000     286094640            15498720            18048000
# 71      38000000             0            11292533           -63048000
#
#     budget_rev_jpy  budget_exp_jpy  total_rev_jpy  total_exp_jpy  ebitda_jpy  \
# 0       1596073659      1218480977     1481444816     1214808560   266636256
# 1        520131183       513537983      531694222      533196194    -1501972
# 2         60624423       336857896       59700000      343259492  -283559492
# 3       1443686856      1134549750     1413647985     1179428415   234219570
# 4        584849501       531541785      602186514      565377107    36809407
# ..             ...             ...            ...            ...         ...
# 67       781382835       648597086      747715083      682250209    65464874
# 68        64582892       329952103       62616000      342013264  -279397264
# 69      1550055097      1205510707     1581439721     1232606346   348833375
# 70       713340109       681880925      704399001      678440713    25958288
# 71        65036624       326941902       63048000      335002363  -271954363
#
#     budget_ebitda_jpy  ebitda_vs_budget_pct data_issue
# 0           377592682                -29.39        NaN
# 1             6593200               -122.78        NaN
# 2          -276233473                 -2.65        NaN
# 3           309137106                -24.23        NaN
# 4            53307716                -30.95        NaN
# ..                ...                   ...        ...
# 67          132785749                -50.70        NaN
# 68         -265369211                 -5.29        NaN
# 69          344544390                  1.24        NaN
# 70           31459184                -17.49        NaN
# 71         -261905278                 -3.84        NaN
#
# [72 rows x 20 columns]

# %%
# Find missing values
missing = df.isnull().sum()
missing = missing[missing > 0]
print("Missing values found:")
print(missing.to_string())
print()

# Flag data with data issue
flagged = df[df["data_issue"].notna()][["ds","division","data_issue"]]
print(f"Flagged rows: {len(flagged)}")
print(flagged.to_string(index=False))
print()
# Out:
# Missing values found:
# usd_jpy_rate    48
# exp_it_jpy       1
# data_issue      71
#
# Flagged rows: 1
#         ds    division                                    data_issue
# 2022-06-01 Asia Export missing IT expense — not reported by division

# %%
# Polish data

# Store time in datetime
df["ds"] = pd.to_datetime(df["ds"])

# Mask missing data, and apply linear interpolation for IT expense
missing_mask = df["exp_it_jpy"].isnull()
df["exp_it_jpy"] = df.groupby("division")["exp_it_jpy"].transform(
    lambda x: x.interpolate(method="linear")
)
print(f"Interpolated {missing_mask.sum()} values")

# Fill NaN with 0 for cost of goods sold (cogs) for HQ since HQ doesn't have cogs
df["exp_cogs_jpy"] = df["exp_cogs_jpy"].fillna(0)
print()
# Out:
# Interpolated 1 values

# %%
# Verify intercompany transaction is net 0, and eliminate intercompany charges from revenue

# intercomany transaction from Japan Domestic to HQ + from Asia Export to HQ should 
# bhave net 0 with amount HQ is receiving (with sone error tolerance)
interco_check = df.groupby("ds")["interco_charge_jpy"].sum()
discrepancies = interco_check[abs(interco_check) > 1000]

if len(discrepancies) == 0:
    print("All intercompany charges net to zero")
else:
    print(f"{len(discrepancies)} months with discrepancies")
    print(discrepancies.to_string())

# External revenue = total revenue - intercompany charges
df["rev_external_jpy"] = df["total_rev_jpy"] - df["interco_charge_jpy"].clip(lower=0)
print()
# Out:
# All intercompany charges net to zero

# %%
# Consolidate data

# group data by month, aggregate by summing
consolidated = df.groupby("ds").agg(
    total_rev_jpy      =("rev_external_jpy",  "sum"),
    total_exp_jpy      =("total_exp_jpy",      "sum"),
    exp_headcount_jpy  =("exp_headcount_jpy",  "sum"),
    exp_it_jpy         =("exp_it_jpy",         "sum"),
    exp_cogs_jpy       =("exp_cogs_jpy",       "sum"),
    exp_compliance_jpy =("exp_compliance_jpy", "sum"),
    budget_rev_jpy     =("budget_rev_jpy",     "sum"),
    budget_exp_jpy     =("budget_exp_jpy",     "sum"),
).reset_index()

# EBITDA:Revenue - Expense, calculate for actual and budget
consolidated["ebitda_jpy"]        = consolidated["total_rev_jpy"] - consolidated["total_exp_jpy"]
consolidated["budget_ebitda_jpy"] = consolidated["budget_rev_jpy"] - consolidated["budget_exp_jpy"]

# Variance for actual vs budget
consolidated["variance_vs_budget_jpy"] = consolidated["ebitda_jpy"] - consolidated["budget_ebitda_jpy"]
consolidated["ebitda_vs_budget_pct"]   = (
    consolidated["variance_vs_budget_jpy"] / consolidated["budget_rev_jpy"] * 100
).round(2)

# Value for prediction
consolidated["y"]  = consolidated["ebitda_jpy"]

print(f"Consolidated to {len(consolidated)} monthly rows")
print()
print(consolidated[["ds","total_rev_jpy","total_exp_jpy","ebitda_jpy","ebitda_vs_budget_pct"]].to_string(index=False))
print()
# Out:
# Consolidated to 24 monthly rows
#
#         ds  total_rev_jpy  total_exp_jpy  ebitda_jpy  ebitda_vs_budget_pct
# 2022-04-01     2013139038     2091264246   -78125208                 -8.55
# 2022-05-01     2015834499     2091865832   -76031333                 -7.81
# 2022-06-01     2091857265     2128370210   -36512945                 -4.97
# 2022-07-01     1855521851     2062528056  -207006205                 -9.36
# 2022-08-01     1816044040     2090809559  -274765519                 -8.74
# 2022-09-01     2085634371     2155201853   -69567482                -11.31
# 2022-10-01     2131040867     2275211302  -144170435                 -4.64
# 2022-11-01     2157086621     2218660559   -61573938                 -7.36
# 2022-12-01     2077939250     2183897866  -105958616                 -8.30
# 2023-01-01     2438841016     2393316846    45524170                 -6.21
# 2023-02-01     2361399861     2275108941    86290920                -10.20
# 2023-03-01     2472249714     2311936408   160313306                -10.72
# 2023-04-01     2064680351     2115373800   -50693449                 -7.18
# 2023-05-01     2093041072     2172875784   -79834712                 -6.84
# 2023-06-01     2084100019     2171066022   -86966003                 -1.83
# 2023-07-01     1922611058     2074692268  -152081210                 -6.98
# 2023-08-01     1953819206     2087689306  -133870100                 -5.86
# 2023-09-01     2074535662     2164803798   -90268136                 -9.98
# 2023-10-01     2154774848     2229266724   -74491876                 -9.37
# 2023-11-01     2159092804     2203287071   -44194267                 -6.78
# 2023-12-01     2085587511     2211111813  -125524302                 -6.98
# 2024-01-01     2440402586     2308126526   132276060                 -2.92
# 2024-02-01     2406149866     2278275473   127874393                 -9.88
# 2024-03-01     2285838722     2246049422    39789300                 -3.19

# %%
# Flag anomalies

# Flag months where EBITDA deviates more than 5% of budget revenue
THRESHOLD = 5
anomalies = consolidated[abs(consolidated["ebitda_vs_budget_pct"]) > THRESHOLD].copy()

print(f"Threshold: EBITDA variance > {THRESHOLD}% of consolidated budget revenue")
print(f"Anomalies detected: {len(anomalies)}")
print()
print(anomalies[["ds","ebitda_jpy","budget_ebitda_jpy","ebitda_vs_budget_pct"]].to_string(index=False))
print()

# Save consolidated data for prediction
consolidated.to_csv("yamato_consolidated.csv", index=False)
print("Saved yamato_consolidated.csv")
# Out:
# ============================================================
# STEP 6: Flagging budget variance anomalies
# ============================================================
# Threshold: EBITDA variance > 5.0% of consolidated budget revenue
# Anomalies detected: 19
#
#         ds  ebitda_jpy  budget_ebitda_jpy  ebitda_vs_budget_pct
# 2022-04-01   -78125208          107952409                 -8.55
# 2022-05-01   -76031333           86962012                 -7.81
# 2022-07-01  -207006205          -20032009                 -9.36
# 2022-08-01  -274765519         -103450898                 -8.74
# 2022-09-01   -69567482          184816077                -11.31
# 2022-11-01   -61573938          108538465                 -7.36
# 2022-12-01  -105958616           72690406                 -8.30
# 2023-01-01    45524170          209265801                 -6.21
# 2023-02-01    86290920          353093901                -10.20
# 2023-03-01   160313306          446417078                -10.72
# 2023-04-01   -50693449          106103132                 -7.18
# 2023-05-01   -79834712           73847184                 -6.84
# 2023-07-01  -152081210          -11591564                 -6.98
# 2023-08-01  -133870100          -11925897                 -5.86
# 2023-09-01   -90268136          133597432                 -9.98
# 2023-10-01   -74491876          146856112                 -9.37
# 2023-11-01   -44194267          109637462                 -6.78
# 2023-12-01  -125524302           26495677                 -6.98
# 2024-02-01   127874393          380347346                 -9.88
#
# ✓ Saved yamato_consolidated.csv — ready for Phase 3 (forecasting)
